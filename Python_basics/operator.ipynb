# %%
print(321 + 12)     # 加法运算，输出333
print(321 - 12)     # 减法运算，输出309
print(321 * 12)     # 乘法运算，输出3852
print(321 / 12)     # 除法运算，输出26.75
print(321 // 12)    # 整除运算，输出26
print(321 % 12)     # 求模运算，输出9
print(321 ** 12)    # 求幂运算，输出1196906950228928915420617322241
# Out:
# 333
# 309
# 3852
# 26.75
# 26
# 9
# 1196906950228928915420617322241

# %%
# 运算符优先级示例
print(2 + 3 * 5)           # 17
print((2 + 3) * 5)         # 25
print((2 + 3) * 5 ** 2)    # 125
print(((2 + 3) * 5) ** 2)  # 625
# Out:
# 17
# 25
# 125
# 625

# %%
# 复合赋值运算符示例
a = 10
b = 3
a += b        # 相当于：a = a + b
a *= a + 2    # 相当于：a = a * (a + 2)
print(a)      # 输出：a = 13 * (13 + 2) = 13 * 15 = 195
# Out:
# 195

# %%
# 海象运算符也是将运算符右侧的值赋值给左边的变量，与赋值运算符不同的是，运算符右侧的值也是整个表达式的值
a = 5
print(a)          # 5
print((a := 10))  # 10 赋值后立刻使用
print(a)          # 10
# Out:
# 5
# 10
# 10

# %%
flag0 = 1 == 1
flag1 = 3 > 2
flag2 = 2 < 1
flag3 = flag1 and flag2 #与 一否全否
flag4 = flag1 or flag2  #或 一对全对
flag5 = not flag0       #非 取反
print('flag0 =', flag0)     # flag0 = True
print('flag1 =', flag1)     # flag1 = True
print('flag2 =', flag2)     # flag2 = False
print('flag3 =', flag3)     # flag3 = False
print('flag4 =', flag4)     # flag4 = True
print('flag5 =', flag5)     # flag5 = False
print(flag1 and not flag2)  # True
print(1 > 2 or 2 == 3)      # False
# Out:
# flag0 = True
# flag1 = True
# flag2 = False
# flag3 = False
# flag4 = True
# flag5 = False
# True
# False
